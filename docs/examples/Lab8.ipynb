# %% [markdown]
# # Demonstration of Lab 8 Functionality

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lweber89/geog510-lab-utils/blob/main/docs/examples/Lab8.ipynb)

# %%
# %pip install geog510-lab-utils

# %%
import geog510_lab_utils.geog510_lab_utils as gu

# %%
m = gu.Map()


m.add_basemap_gui()

m
